# %% [markdown]
# # SSB Oppdateringsdetector – Debug-verktøy
#
# Fryst celle flyttet ut fra `03_ssb_oppdateringsdetector.ipynb`.
#
# ## Formål
# Tømmer `statbank_staging.pipeline.ssb_load_queue` manuelt.
# Brukes kun ved debugging/feilretting – **kjøres ikke som del av normal pipeline-flyt**.
#
# ---------

# %%
spark.sql("""
    DELETE FROM statbank_staging.pipeline.ssb_load_queue
""")
print("ssb_load_queue tømt")
